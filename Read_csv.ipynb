# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
data_frames = pd.read_csv("~/Dataset/comptage_velo_2018.csv", parse_dates=['Date'], index_col='Date')

# %%
data_frames[:3]
# Out:
#            Unnamed: 1  Berri1  Boyer  Boyer 2  Brébeuf  Christophe-Colomb  \
# Date
# 2018-01-01      00:00      29     30     18.0        2                8.0
# 2018-02-01      00:00      94     71     32.0        0                6.0
# 2018-03-01      00:00     200    149     54.0        0               30.0
#
#             CSC (Côte Sainte-Catherine)  Eco-Display Parc Stanley  \
# Date
# 2018-01-01                            7                       NaN
# 2018-02-01                           23                       NaN
# 2018-03-01                           58                       NaN
#
#             Eco-Totem - Métro Laurier  Edmond Valade  ...  Parc  PierDup  \
# Date                                                  ...
# 2018-01-01                         52              0  ...    15        0
# 2018-02-01                         78              0  ...    38        0
# 2018-03-01                        112              0  ...    76        4
#
# ...

# %%
data_frames['Berri1'].plot()

# %%
data_frames.plot(figsize=(15, 10))

# %%
data_frames.count(axis=1)
# Out:
# Date
# 2018-01-01    22
# 2018-02-01    22
# 2018-03-01    22
# 2018-04-01    21
# 2018-05-01    21
#               ..
# 2018-12-27    24
# 2018-12-28    24
# 2018-12-29    24
# 2018-12-30    24
# 2018-12-31    24
# Length: 365, dtype: int64

# %%
data_frames = pd.read_csv("~/Dataset/comptage_velo_2018.csv", parse_dates=['Date'], dayfirst=True, index_col="Date")

# %%
data_frames[:3]
# Out:
#            Unnamed: 1  Berri1  Boyer  Boyer 2  Brébeuf  Christophe-Colomb  \
# Date
# 2018-01-01      00:00      29     30     18.0        2                8.0
# 2018-01-02      00:00      94     71     32.0        0                6.0
# 2018-01-03      00:00     200    149     54.0        0               30.0
#
#             CSC (Côte Sainte-Catherine)  Eco-Display Parc Stanley  \
# Date
# 2018-01-01                            7                       NaN
# 2018-01-02                           23                       NaN
# 2018-01-03                           58                       NaN
#
#             Eco-Totem - Métro Laurier  Edmond Valade  ...  Parc  PierDup  \
# Date                                                  ...
# 2018-01-01                         52              0  ...    15        0
# 2018-01-02                         78              0  ...    38        0
# 2018-01-03                        112              0  ...    76        4
#
# ...

# %%
data_frames['Berri1'].plot(figsize=(25,10))
