# %%
# %matplotlib inline 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
complaints = pd.read_csv("~/Dataset/311_Service_Requests_from_2010_to_Present.csv")

# %%
complaints
# Out:
#                             Unique Key            Created Date  \
# 0                             40085270  08/23/2018 11:23:19 AM
# 1                             40085271  08/23/2018 10:23:36 AM
# 2                             40085272  08/23/2018 07:24:23 PM
# 3                             40085273  08/23/2018 12:31:27 PM
# 4                             40085274  08/23/2018 05:13:21 PM
# ...                                ...                     ...
# 200932                        40345844  09/21/2018 09:09:00 AM
# 200933                  "error" : true                     NaN
# 200934    "message" : "Internal error"                     NaN
# 200935                  "status" : 500                     NaN
# 200936                               }                     NaN
#
#                    Closed Date Agency  \
# 0       08/29/2018 09:11:28 AM    HPD
# 1       08/25/2018 12:00:00 AM    DOB
# 2       08/24/2018 09:03:37 AM    HPD
# 3       09/10/2018 09:58:00 AM    HPD
# ...

# %%
complaints[['Complaint Type', 'Agency Name']]
# Out:
#                        Complaint Type  \
# 0                UNSANITARY CONDITION
# 1       General Construction/Plumbing
# 2                              SAFETY
# 3                              SAFETY
# 4                UNSANITARY CONDITION
# ...                               ...
# 200932         Street Light Condition
# 200933                            NaN
# 200934                            NaN
# 200935                            NaN
# 200936                            NaN
#
#                                               Agency Name
# 0       Department of Housing Preservation and Develop...
# 1                                 Department of Buildings
# 2       Department of Housing Preservation and Develop...
# 3       Department of Housing Preservation and Develop...
# 4       Department of Housing Preservation and Develop...
# ...                                                   ...
# 200932                       Department of Transportation
# ...

# %%
mostAppear = complaints['Complaint Type'].value_counts()

# %%
mostAppear[:10]
# Out:
# Noise - Residential                    18788
# Request Large Bulky Item Collection    16512
# Illegal Parking                        14322
# Blocked Driveway                       11442
# Noise - Street/Sidewalk                 9600
# UNSANITARY CONDITION                    8899
# Street Condition                        6410
# PAINT/PLASTER                           5187
# Water System                            4562
# Sanitation Condition                    4355
# Name: Complaint Type, dtype: int64

# %%
mostAppear[:10].plot(kind="bar")
